# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('hotel_booking.csv')

# %%
# Bus atliekma dviejų viešbučių "Resort Hotel" ir "City Hotel" analizė. Abu viešbučiai yra Portugalijoje, 
# "Resort Hotel" yra kurortiniame Algravės regione, "City Hotel" yra Lisabonos mieste. Tarp jų yra 280 km atstumas
# ir abi vietos ribojasi su Šiaurės Atlantu.

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        109               2016
# 1       Resort Hotel            0        109               2016
# 2       Resort Hotel            1          2               2016
# 3       Resort Hotel            0         88               2016
# 4       Resort Hotel            1         20               2016
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         17               2016
# 119386    City Hotel            0        177               2016
# 119387    City Hotel            0        107               2016
# 119388    City Hotel            0        310               2016
# 119389    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                 January                         1
# 1                 January                         1
# 2                 January                         1
# 3                 January                         1
# 4                 January                         1
# ...                   ...                       ...
# 119385           December                        53
# 119386           December                        53
# 119387           December                        53
# 119388           December                        53
# 119389           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         30                        2
# 119387                         31                        2
# 119388                         27                        2
# 119389                         27                        2
#
#         stays_in_week_nights  adults  ...    customer_type     adr  \
# 0                          1       2  ...  Transient-Party   59.94
# 1                          1       2  ...  Transient-Party  116.10
# 2                          1       2  ...        Transient   89.00
# 3                          2       2  ...        Transient   73.46
# 4                          2       2  ...        Transient  119.00
# ...                      ...     ...  ...              ...     ...
# 119385                     5       2  ...        Transient   90.34
# 119386                     5       0  ...        Transient    1.29
# 119387                     5       2  ...        Transient  103.57
# 119388                    10       2  ...  Transient-Party   68.57
# 119389                    10       2  ...  Transient-Party   68.57
#
#        required_car_parking_spaces total_of_special_requests  \
# 0                                0                         1
# 1                                1                         1
# 2                                0                         1
# 3                                0                         2
# 4                                0                         0
# ...                            ...                       ...
# 119385                           0                         1
# 119386                           0                         2
# 119387                           0                         0
# 119388                           0                         2
# 119389                           0                         2
#
#        reservation_status reservation_status_date                 name  \
# 0               Check-Out              02/01/2016         Sherri Ortiz
# 1               Check-Out              02/01/2016           John Patel
# 2                 No-Show              01/01/2016       Ashley Stewart
# 3               Check-Out              03/01/2016       Vanessa Taylor
# 4                Canceled              22/12/2015          Erik Jordan
# ...                   ...                     ...                  ...
# 119385          Check-Out              06/01/2017         Billy Howell
# 119386          Check-Out              06/01/2017          Mark Torres
# 119387          Check-Out              07/01/2017  Elizabeth Davenport
# 119388          Check-Out              08/01/2017     Daniel Patterson
# 119389          Check-Out              08/01/2017       Carolyn Peters
#
#                                email  phone-number       credit_card
# 0            Ortiz.Sherri37@mail.com  315-741-7352  ************2125
# 1                  JPatel@yandex.com  779-515-8181  ************9807
# 2           Ashley_Stewart47@aol.com  328-942-1542  ************6029
# 3            Vanessa.T74@outlook.com  684-380-1411  ************1935
# 4             Erik_Jordan@yandex.com  649-894-9639  ************2421
# ...                              ...           ...               ...
# 119385    Billy.Howell11@hotmail.com  597-460-5171  ************8509
# 119386            Mark.T@hotmail.com  735-191-4996  ************3411
# 119387  Elizabeth_Davenport@mail.com  516-265-9554  ************5640
# 119388              Daniel.P@aol.com  531-431-4227  ************5793
# 119389       Carolyn.Peters@mail.com  861-330-6467  ************4862
#
# [119390 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
#  32  name                            119390 non-null  object
#  33  email                           119390 non-null  object
#  34  phone-number                    119390 non-null  object
#  35  credit_card                     119390 non-null  object
# dtypes: float64(4), int64(16), object(16)
# memory usage: 32.8+ MB

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  119386.000000  119390.000000      119390.000000
# mean        0.103890       0.007949           0.031912
# std         0.398561       0.097436           0.175767
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
# Analizė
# 1. Kiek buvo atšaukta užsakymų
# 2. Iš kokių šalių atvyksta daugiausiai žmonių
# 3. Užsakymai pagal rinkos segmentus
# 4. Kokia yra vidutinė paros kaina 
# 5. Kaip kinta vidutinį paros kaina per metus
# 6. Kokiais mėnesiais atvyksta daugiausiai svečių
# 7. Kaip ilgai svečiai apsistoja viešbučiuose

# %%
# KIEK BUVO ATŠAUKTA UŽSAKYMŲ


df[df['is_canceled']== 1]['is_canceled'].count()
#print(df.isin({'is_canceled': [True]}))
# Out:
# 44224

# %%
df1=df[(df['is_canceled']==1) & (df['hotel']=='City Hotel')]

len(df1)
# Out:
# 33102

# %%
df2=df[(df['is_canceled']==1) & (df['hotel']=='Resort Hotel')]

len(df2)
# Out:
# 11122

# %%
# Bendras procentas atšauktų užsakymų nuo visų užsakymų sumos
x = round((44224*100)/119390),2
x
# Out:
# (37, 2)

# %%
# Procentas atšauktų užsakymų City Hotel
y = round((33102*100)/44224),2
y
# Out:
# (75, 2)

# %%
# Procentas atšauktų užsakymų Resort Hotel
z = round((11122*100)/44224),2
z
# Out:
# (25, 2)

# %%
# Išvada: City hotel atnuliavimo procentas labai aukštas

# %%
# IŠ KOKIŲ ŠALIŲ ATVYKSTA SVEČIAI

df=df[df.is_canceled !=1]# palikau, kur adr vertes nelygios 1

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        109               2016
# 1       Resort Hotel            0        109               2016
# 3       Resort Hotel            0         88               2016
# 6       Resort Hotel            0         88               2016
# 32      Resort Hotel            0        110               2016
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         17               2016
# 119386    City Hotel            0        177               2016
# 119387    City Hotel            0        107               2016
# 119388    City Hotel            0        310               2016
# 119389    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                 January                         1
# 1                 January                         1
# 3                 January                         1
# 6                 January                         1
# 32                January                         1
# ...                   ...                       ...
# 119385           December                        53
# 119386           December                        53
# 119387           December                        53
# 119388           December                        53
# 119389           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 3                               1                        0
# 6                               1                        0
# 32                              2                        2
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         30                        2
# 119387                         31                        2
# 119388                         27                        2
# 119389                         27                        2
#
#         stays_in_week_nights  adults  ...    customer_type     adr  \
# 0                          1       2  ...  Transient-Party   59.94
# 1                          1       2  ...  Transient-Party  116.10
# 3                          2       2  ...        Transient   73.46
# 6                          2       2  ...        Transient   90.17
# 32                         5       2  ...        Transient   46.93
# ...                      ...     ...  ...              ...     ...
# 119385                     5       2  ...        Transient   90.34
# 119386                     5       0  ...        Transient    1.29
# 119387                     5       2  ...        Transient  103.57
# 119388                    10       2  ...  Transient-Party   68.57
# 119389                    10       2  ...  Transient-Party   68.57
#
#        required_car_parking_spaces total_of_special_requests  \
# 0                                0                         1
# 1                                1                         1
# 3                                0                         2
# 6                                0                         2
# 32                               0                         3
# ...                            ...                       ...
# 119385                           0                         1
# 119386                           0                         2
# 119387                           0                         0
# 119388                           0                         2
# 119389                           0                         2
#
#        reservation_status reservation_status_date                 name  \
# 0               Check-Out              02/01/2016         Sherri Ortiz
# 1               Check-Out              02/01/2016           John Patel
# 3               Check-Out              03/01/2016       Vanessa Taylor
# 6               Check-Out              03/01/2016           Eric White
# 32              Check-Out              09/01/2016     Christopher Pugh
# ...                   ...                     ...                  ...
# 119385          Check-Out              06/01/2017         Billy Howell
# 119386          Check-Out              06/01/2017          Mark Torres
# 119387          Check-Out              07/01/2017  Elizabeth Davenport
# 119388          Check-Out              08/01/2017     Daniel Patterson
# 119389          Check-Out              08/01/2017       Carolyn Peters
#
#                                email  phone-number       credit_card
# 0            Ortiz.Sherri37@mail.com  315-741-7352  ************2125
# 1                  JPatel@yandex.com  779-515-8181  ************9807
# 3            Vanessa.T74@outlook.com  684-380-1411  ************1935
# 6                  EWhite@yandex.com  103-323-0529  ************3343
# 32       Christopher.Pugh@yandex.com  780-440-1080  ************1278
# ...                              ...           ...               ...
# 119385    Billy.Howell11@hotmail.com  597-460-5171  ************8509
# 119386            Mark.T@hotmail.com  735-191-4996  ************3411
# 119387  Elizabeth_Davenport@mail.com  516-265-9554  ************5640
# 119388              Daniel.P@aol.com  531-431-4227  ************5793
# 119389       Carolyn.Peters@mail.com  861-330-6467  ************4862
#
# [75166 rows x 36 columns]

# %%
# UŽSAKYMAI PAGAL RINKOS SEGMENTUS

# %%
Aviation=(df['market_segment']=='Aviation').sum()
Direct=(df['market_segment']=='Direct').sum()
Corporate =(df['market_segment']=='Corporate').sum()
Online_TA=(df['market_segment']=='Online TA').sum()
Groups=(df['market_segment']=='Groups').sum()
Offline_TA_TO=(df['market_segment']=='Offline TA/TO').sum()
Complementary=(df['market_segment']=='Complementaty').sum()
Undefined=(df['market_segment']=='Undefined').sum()
plt.pie([Aviation, Direct, Corporate,Groups, Complementary,Undefined], labels=['Aviation', 'Direct','Corporate','Groups', 'Complementary','Undefined'],autopct='%.2f%%')
plt.show()

# %%
# KIEK VIDUTININIŠKAI SVEČIAI MOKA ABIEJUOSE VIEŠBUČIUOSE

# %%
# išimu nulinias vertes iš df
# randu kur nuliai
def funkcija (df):
    L= [0]
    rez = df[df['adr'].isin(L)]
    print(rez.adr) # svarbu atitraukimas
 
funkcija(df)
# Out:
# 83        0.0
# 359       0.0
# 478       0.0
# 506       0.0
# 509       0.0
#          ...
# 118736    0.0
# 118809    0.0
# 118858    0.0
# 119084    0.0
# 119169    0.0
# Name: adr, Length: 1746, dtype: float64

# %%
df=df[df.adr !=0]# išimu reikšmes, kur adr vertes lygios 0
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        109               2016
# 1       Resort Hotel            0        109               2016
# 3       Resort Hotel            0         88               2016
# 6       Resort Hotel            0         88               2016
# 32      Resort Hotel            0        110               2016
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         17               2016
# 119386    City Hotel            0        177               2016
# 119387    City Hotel            0        107               2016
# 119388    City Hotel            0        310               2016
# 119389    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                 January                         1
# 1                 January                         1
# 3                 January                         1
# 6                 January                         1
# 32                January                         1
# ...                   ...                       ...
# 119385           December                        53
# 119386           December                        53
# 119387           December                        53
# 119388           December                        53
# 119389           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 3                               1                        0
# 6                               1                        0
# 32                              2                        2
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         30                        2
# 119387                         31                        2
# 119388                         27                        2
# 119389                         27                        2
#
#         stays_in_week_nights  adults  ...     adr  \
# 0                          1       2  ...   59.94
# 1                          1       2  ...  116.10
# 3                          2       2  ...   73.46
# 6                          2       2  ...   90.17
# 32                         5       2  ...   46.93
# ...                      ...     ...  ...     ...
# 119385                     5       2  ...   90.34
# 119386                     5       0  ...    1.29
# 119387                     5       2  ...  103.57
# 119388                    10       2  ...   68.57
# 119389                    10       2  ...   68.57
#
#         required_car_parking_spaces total_of_special_requests  \
# 0                                 0                         1
# 1                                 1                         1
# 3                                 0                         2
# 6                                 0                         2
# 32                                0                         3
# ...                             ...                       ...
# 119385                            0                         1
# 119386                            0                         2
# 119387                            0                         0
# 119388                            0                         2
# 119389                            0                         2
#
#        reservation_status reservation_status_date                 name  \
# 0               Check-Out              02/01/2016         Sherri Ortiz
# 1               Check-Out              02/01/2016           John Patel
# 3               Check-Out              03/01/2016       Vanessa Taylor
# 6               Check-Out              03/01/2016           Eric White
# 32              Check-Out              09/01/2016     Christopher Pugh
# ...                   ...                     ...                  ...
# 119385          Check-Out              06/01/2017         Billy Howell
# 119386          Check-Out              06/01/2017          Mark Torres
# 119387          Check-Out              07/01/2017  Elizabeth Davenport
# 119388          Check-Out              08/01/2017     Daniel Patterson
# 119389          Check-Out              08/01/2017       Carolyn Peters
#
#                                email  phone-number       credit_card  \
# 0            Ortiz.Sherri37@mail.com  315-741-7352  ************2125
# 1                  JPatel@yandex.com  779-515-8181  ************9807
# 3            Vanessa.T74@outlook.com  684-380-1411  ************1935
# 6                  EWhite@yandex.com  103-323-0529  ************3343
# 32       Christopher.Pugh@yandex.com  780-440-1080  ************1278
# ...                              ...           ...               ...
# 119385    Billy.Howell11@hotmail.com  597-460-5171  ************8509
# 119386            Mark.T@hotmail.com  735-191-4996  ************3411
# 119387  Elizabeth_Davenport@mail.com  516-265-9554  ************5640
# 119388              Daniel.P@aol.com  531-431-4227  ************5793
# 119389       Carolyn.Peters@mail.com  861-330-6467  ************4862
#
#        numberOFpeopleINnumber
# 0                         2.0
# 1                         4.0
# 3                         2.0
# 6                         3.0
# 32                        2.0
# ...                       ...
# 119385                    2.0
# 119386                    0.0
# 119387                    2.0
# 119388                    2.0
# 119389                    2.0
#
# [73420 rows x 37 columns]

# %%
df['numberOFpeopleINnumber']=df['adults']+df['children']+df['babies']
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        109               2016
# 1       Resort Hotel            0        109               2016
# 3       Resort Hotel            0         88               2016
# 6       Resort Hotel            0         88               2016
# 32      Resort Hotel            0        110               2016
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         17               2016
# 119386    City Hotel            0        177               2016
# 119387    City Hotel            0        107               2016
# 119388    City Hotel            0        310               2016
# 119389    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                 January                         1
# 1                 January                         1
# 3                 January                         1
# 6                 January                         1
# 32                January                         1
# ...                   ...                       ...
# 119385           December                        53
# 119386           December                        53
# 119387           December                        53
# 119388           December                        53
# 119389           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 3                               1                        0
# 6                               1                        0
# 32                              2                        2
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         30                        2
# 119387                         31                        2
# 119388                         27                        2
# 119389                         27                        2
#
#         stays_in_week_nights  adults  ...     adr  \
# 0                          1       2  ...   59.94
# 1                          1       2  ...  116.10
# 3                          2       2  ...   73.46
# 6                          2       2  ...   90.17
# 32                         5       2  ...   46.93
# ...                      ...     ...  ...     ...
# 119385                     5       2  ...   90.34
# 119386                     5       0  ...    1.29
# 119387                     5       2  ...  103.57
# 119388                    10       2  ...   68.57
# 119389                    10       2  ...   68.57
#
#         required_car_parking_spaces total_of_special_requests  \
# 0                                 0                         1
# 1                                 1                         1
# 3                                 0                         2
# 6                                 0                         2
# 32                                0                         3
# ...                             ...                       ...
# 119385                            0                         1
# 119386                            0                         2
# 119387                            0                         0
# 119388                            0                         2
# 119389                            0                         2
#
#        reservation_status reservation_status_date                 name  \
# 0               Check-Out              02/01/2016         Sherri Ortiz
# 1               Check-Out              02/01/2016           John Patel
# 3               Check-Out              03/01/2016       Vanessa Taylor
# 6               Check-Out              03/01/2016           Eric White
# 32              Check-Out              09/01/2016     Christopher Pugh
# ...                   ...                     ...                  ...
# 119385          Check-Out              06/01/2017         Billy Howell
# 119386          Check-Out              06/01/2017          Mark Torres
# 119387          Check-Out              07/01/2017  Elizabeth Davenport
# 119388          Check-Out              08/01/2017     Daniel Patterson
# 119389          Check-Out              08/01/2017       Carolyn Peters
#
#                                email  phone-number       credit_card  \
# 0            Ortiz.Sherri37@mail.com  315-741-7352  ************2125
# 1                  JPatel@yandex.com  779-515-8181  ************9807
# 3            Vanessa.T74@outlook.com  684-380-1411  ************1935
# 6                  EWhite@yandex.com  103-323-0529  ************3343
# 32       Christopher.Pugh@yandex.com  780-440-1080  ************1278
# ...                              ...           ...               ...
# 119385    Billy.Howell11@hotmail.com  597-460-5171  ************8509
# 119386            Mark.T@hotmail.com  735-191-4996  ************3411
# 119387  Elizabeth_Davenport@mail.com  516-265-9554  ************5640
# 119388              Daniel.P@aol.com  531-431-4227  ************5793
# 119389       Carolyn.Peters@mail.com  861-330-6467  ************4862
#
#        numberOFpeopleINnumber
# 0                         2.0
# 1                         4.0
# 3                         2.0
# 6                         3.0
# 32                        2.0
# ...                       ...
# 119385                    2.0
# 119386                    0.0
# 119387                    2.0
# 119388                    2.0
# 119389                    2.0
#
# [73420 rows x 37 columns]

# %%
df=df[df.numberOFpeopleINnumber !=0]


df['pricePERperson']=round(df['adr']/df['numberOFpeopleINnumber'])
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        109               2016
# 1       Resort Hotel            0        109               2016
# 3       Resort Hotel            0         88               2016
# 6       Resort Hotel            0         88               2016
# 32      Resort Hotel            0        110               2016
# ...              ...          ...        ...                ...
# 119384    City Hotel            0        173               2016
# 119385    City Hotel            0         17               2016
# 119387    City Hotel            0        107               2016
# 119388    City Hotel            0        310               2016
# 119389    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 0                 January                         1
# 1                 January                         1
# 3                 January                         1
# 6                 January                         1
# 32                January                         1
# ...                   ...                       ...
# 119384           December                        53
# 119385           December                        53
# 119387           December                        53
# 119388           December                        53
# 119389           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 3                               1                        0
# 6                               1                        0
# 32                              2                        2
# ...                           ...                      ...
# 119384                         26                        3
# 119385                         30                        2
# 119387                         31                        2
# 119388                         27                        2
# 119389                         27                        2
#
#         stays_in_week_nights  adults  ...  required_car_parking_spaces  \
# 0                          1       2  ...                            0
# 1                          1       2  ...                            1
# 3                          2       2  ...                            0
# 6                          2       2  ...                            0
# 32                         5       2  ...                            0
# ...                      ...     ...  ...                          ...
# 119384                     8       2  ...                            0
# 119385                     5       2  ...                            0
# 119387                     5       2  ...                            0
# 119388                    10       2  ...                            0
# 119389                    10       2  ...                            0
#
#         total_of_special_requests reservation_status reservation_status_date  \
# 0                               1          Check-Out              02/01/2016
# 1                               1          Check-Out              02/01/2016
# 3                               2          Check-Out              03/01/2016
# 6                               2          Check-Out              03/01/2016
# 32                              3          Check-Out              09/01/2016
# ...                           ...                ...                     ...
# 119384                          1          Check-Out              06/01/2017
# 119385                          1          Check-Out              06/01/2017
# 119387                          0          Check-Out              07/01/2017
# 119388                          2          Check-Out              08/01/2017
# 119389                          2          Check-Out              08/01/2017
#
#                        name                         email  phone-number  \
# 0              Sherri Ortiz       Ortiz.Sherri37@mail.com  315-741-7352
# 1                John Patel             JPatel@yandex.com  779-515-8181
# 3            Vanessa Taylor       Vanessa.T74@outlook.com  684-380-1411
# 6                Eric White             EWhite@yandex.com  103-323-0529
# 32         Christopher Pugh   Christopher.Pugh@yandex.com  780-440-1080
# ...                     ...                           ...           ...
# 119384          Gary Kelley        GaryKelley@hotmail.com  137-344-4957
# 119385         Billy Howell    Billy.Howell11@hotmail.com  597-460-5171
# 119387  Elizabeth Davenport  Elizabeth_Davenport@mail.com  516-265-9554
# 119388     Daniel Patterson              Daniel.P@aol.com  531-431-4227
# 119389       Carolyn Peters       Carolyn.Peters@mail.com  861-330-6467
#
#              credit_card  numberOFpeopleINnumber pricePERperson
# 0       ************2125                     2.0           30.0
# 1       ************9807                     4.0           29.0
# 3       ************1935                     2.0           37.0
# 6       ************3343                     3.0           30.0
# 32      ************1278                     2.0           23.0
# ...                  ...                     ...            ...
# 119384  ************5644                     3.0           39.0
# 119385  ************8509                     2.0           45.0
# 119387  ************5640                     2.0           52.0
# 119388  ************5793                     2.0           34.0
# 119389  ************4862                     2.0           34.0
#
# [73389 rows x 38 columns]

# %%
df['pricePERperson'].max()
# Out:
# 510.0

# %%
df[df['hotel']=='City Hotel']['pricePERperson'].mean() # vidutinė kaina 1 žmogui parai
# Out:
# 60.42782419823134

# %%
df[df['hotel']=='Resort Hotel']['pricePERperson'].mean()
# Out:
# 48.302829854969936

# %%
df=df[(df['arrival_date_year']==2016) & (df['pricePERperson']<2700)] # čia pašalinu atsitiktinį kainos padidėjimą

        
sns.set(rc={'figure.figsize':(15,20)})
sns.boxplot(x='reserved_room_type', y ='pricePERperson', hue='hotel', data=df)
# Out:
# <Axes: xlabel='reserved_room_type', ylabel='pricePERperson'>

# %%
# Išvada: kainos abiejuose viešbučiuose pasiskirsto skirtingai pagal kambario tipą, City hotel brangiausi E ir G tipo numeriai, Resort Hotel F ir C

# %%
# KAIP VARIJUOJA KAINA METŲ BĖGYJE

# %%
df=df[(df['arrival_date_year']==2016) & (df['pricePERperson']<500)] # cia pašalinu atsitiktinį kainos padidėjimą

        
sns.set(rc={'figure.figsize':(20,20 )})
#sns.lineplot(data=df, x = 'arrival_date_month', y ='kaina_vienam_zmogui', hue="hotel")

sns.boxplot(x='arrival_date_month', y ='pricePERperson', hue='hotel', data=df)
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='pricePERperson'>

# %%
# Išvada: Resort hotel yra kurortinėje zonoje, todėl kainos kyla vasaros sezono metu, o City hotel ,esančio mieste, kaina ne taip stipriai varijuoja, mažiau pasireiškia sezoniškumas

# %%
# KOKIE MĖNESIAI LABAUSIAI POPULIARŪS

# %%
df=df[(df['arrival_date_year']==2016) & (df['numberOFpeopleINnumber']<6)] # cia pašalinu atsitiktinį  padidėjimą
sns.set(rc={'figure.figsize':(15,20)})
sns.lineplot(x='arrival_date_month', y ='numberOFpeopleINnumber', hue='hotel', data=df, sort=False)
#sns.boxplot(x='arrival_date_month', y ='zmoniu_skaicius_numeryje', hue='hotel', data=df)
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='numberOFpeopleINnumber'>

# %%
# Išvada: viešbučiams svarbu planuoti užimtumą, šiame grafike pavaizduota kokių kambarių dviviečių ar triviečių kokiais mėnesiais užsakoma daugiausiai. Abiejų viešbučių
# kreivės panašios t.y. vasaros mėnesiais daugiau atvyksta šeimos su vaikais, todėl populiariausi triviečiai kambariai. City hotel trivičiai reikalingi ir žiemą gruodžio mėnesį

# %%
# SVEČIŲ PASISKIRSTZMAS MĖNESIAIS

# %%
df[df['hotel']=='Resort Hotel']['arrival_date_month'].value_counts() # suskaičiuoju atvykusiųjų skaičių į Resort Hotel kiekvienais metais
# Out:
# October      1383
# March        1371
# April        1307
# May          1285
# August       1093
# February     1086
# September    1058
# November     1029
# December     1006
# July          967
# June          966
# January       738
# Name: arrival_date_month, dtype: int64

# %%
df[df['hotel']=='City Hotel']['arrival_date_month'].value_counts() # suskaičiuoju atvykusiųjų skaičių į City Hotel kiekvienais metais
# Out:
# September    2264
# October      2218
# May          2173
# June         2169
# August       2102
# July         2050
# April        1986
# March        1900
# November     1704
# February     1407
# December     1367
# January       894
# Name: arrival_date_month, dtype: int64

# %%
sns.countplot(x='arrival_date_month',hue='hotel',data=df) # lyginu atvykusiųjų skaičių kiekviename viešbutyje
# Out:
# <Axes: xlabel='arrival_date_month', ylabel='count'>

# %%
# Išvada - City hotel nuo kovo iki lapkričio svečių kiekis stabilus maždaug 2000 svečių per mėnesį, Resort Hotel apsistoja 1300 svečių  spalį, kovą, balandį ir gegužę

# %%
# KOKIAM LAIKOTARPIUI SVEČIAI APSISTOJA VIEŠBUČIUOSE


df[df['hotel']=='Resort Hotel']['stays_in_week_nights'].value_counts() # suskaičiuoju kiek parų apsistoja svečiai
# Out:
# 1     3684
# 2     2321
# 5     2255
# 3     1948
# 4     1035
# 0      908
# 10     330
# 6      292
# 7      271
# 8      158
# 9       45
# 20      13
# 15      10
# 11       5
# 13       5
# 12       4
# 25       2
# 30       1
# 50       1
# 14       1
# Name: stays_in_week_nights, dtype: int64

# %%
df[df['hotel']=='City Hotel']['stays_in_week_nights'].value_counts() # suskaičiuoju kiek parų apsistoja svečiai City hotel
# Out:
# 2     6495
# 1     6493
# 3     4705
# 4     1739
# 0     1611
# 5      969
# 6       97
# 7       41
# 8       38
# 10      25
# 9        8
# 11       4
# 12       2
# 13       2
# 14       1
# 15       1
# 18       1
# 17       1
# 25       1
# Name: stays_in_week_nights, dtype: int64

# %%
# BENDRA IŠVADA>viešbučiai formuluodami kainų politiką, turi atsižvelgti į labai daug veiksnių. City hotel esantis mieste, sostineje Lisabonoje
# išvengia žmonių strauto sezoniškumo, bet turi koncentruoti savo dėmesį į labai aukštą užsakymų atšaukimo procentą. Resort hotel labiau priklauso nuo sezoniškumo,
# todėl turėtų imtis papildomų priemonių kaip pritraukti daugiau svečių ne sezono metu.
